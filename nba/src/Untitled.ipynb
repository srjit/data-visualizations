# %%
# %matplotlib inline

# %%
import pandas as pd
import dateutil

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/NBA_player_of_the_week.csv")

# %%
data["Draft Year"].unique()
# Out:
# array([1978, 1982, 1979, 1969, 1980, 1981, 1974, 1984, 1975, 1977, 1976,
#        1983, 1985, 1972, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1996, 1997, 1995, 1998, 1999, 2001, 2000, 2003, 2002, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2015, 2014,
#        2016])

# %%
min(data.Height)
# Out:
# '5-10'

# %%
data[["Player"]].groupby("Player")["Real_value"].sum().reset_index(name="count").sort_values(by="count",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-c38bbce9e6fb> in <module>()
#       1 data
#       2
# ----> 3 data[["Player"]].groupby("Player")["Real_value"].sum().reset_index(name="count").sort_values(by="count",ascending=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: Real_value'

# %%
data.Player.value_counts()
# Out:
# LeBron James           61
# Kobe Bryant            33
# Kevin Durant           26
# Michael Jordan         25
# Allen Iverson          23
# Karl Malone            23
# Tim Duncan             23
# Kevin Garnett          20
# Shaquille O'Neal       20
# Dwyane Wade            19
# James Harden           18
# Russell Westbrook      18
# Carmelo Anthony        18
# Dwight Howard          18
# Paul Pierce            17
# Jason Kidd             17
# Dirk Nowitzki          16
# David Robinson         15
# Chris Paul             13
# Stephen Curry          13
# Patrick Ewing          12
# Tracy McGrady          12
# Magic Johnson          12
# Hakeem Olajuwon        12
# Clyde Drexler          11
# Charles Barkley        11
# Vince Carter           11
# DeMar DeRozan          10
# LaMarcus Aldridge      10
# Chris Webber            9
#                        ..
# Jamal Crawford          1
# Danny Granger           1
# Mehmet Okur             1
# Kenny Anderson          1
# ...

# %%
data["height"] = pd.to_numeric(data["Height"].apply(lambda x : x.replace("-",".")))

# %%
data['Season short'].unique()


#average height for each position?
data.groupby("Position")['height'].mean()
# Out:
# Position
# C      6.796415
# F      6.719213
# F-C    6.900000
# FC     6.308313
# G      6.268852
# G-F    6.666667
# GF     6.751064
# PF     6.568227
# PG     6.215333
# SF     6.757983
# SG     6.546951
# Name: height, dtype: float64

# %%
data.groupby("Player").size().reset_index(name="count")
# Out:
#                  Player  count
# 0           Aaron McKie      1
# 1        Adrian Dantley      1
# 2         Al Harrington      1
# 3            Al Horford      3
# 4          Al Jefferson      7
# 5          Alex English      4
# 6         Allan Houston      1
# 7         Allen Iverson     23
# 8       Alonzo Mourning      6
# 9       Alvin Robertson      3
# 10    Amar'e Stoudemire      8
# 11       Andre Drummond      3
# 12         Andre Miller      4
# 13     Andrei Kirilenko      2
# 14         Andrew Bogut      1
# 15         Andrew Bynum      3
# 16       Antawn Jamison      1
# 17        Anthony Davis      5
# 18       Antoine Walker      2
# 19      Antonio McDyess      2
# 20        Armen Gilliam      1
# 21      Arvydas Sabonis      1
# 22          Baron Davis      6
# 23           Ben Gordon      4
# 24          Ben Simmons      1
# 25          Ben Wallace      5
# 26         Bernard King      3
# 27        Blake Griffin      6
# 28         Bobby Hansen      1
# ...

# %%
data.groupby(["Player","Position"]).size().reset_index(name="count")
# Out:
#                  Player Position  count
# 0           Aaron McKie        G      1
# 1        Adrian Dantley       SF      1
# 2         Al Harrington        F      1
# 3            Al Horford       FC      3
# 4          Al Jefferson       FC      7
# 5          Alex English       SF      4
# 6         Allan Houston        G      1
# 7         Allen Iverson        G     23
# 8       Alonzo Mourning        C      6
# 9       Alvin Robertson       SG      3
# 10    Amar'e Stoudemire       FC      8
# 11       Andre Drummond        C      3
# 12         Andre Miller       PG      4
# 13     Andrei Kirilenko       PF      2
# 14         Andrew Bogut        C      1
# 15         Andrew Bynum        C      3
# 16       Antawn Jamison        F      1
# 17        Anthony Davis       PF      5
# 18       Antoine Walker        F      2
# 19      Antonio McDyess        F      2
# 20        Armen Gilliam       PF      1
# 21      Arvydas Sabonis        C      1
# ...

# %%
import numpy as np

foo = data.groupby(["Player","Position","Height"]).size().reset_index(name="count")

foo["Height"] = foo["Height"].apply(lambda x : float(x.replace("-",".")))


ht_data = foo.groupby("Position")["Height"].mean().reset_index(name="mean")

# %%
ht_data.to_csv("data.csv")
